# %% [markdown]
# ## Sorting Data

# %%
import pandas as pd

# %%
df=pd.read_csv('data.csv')

# %%
df.head(3)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
# 2                    Never  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
# 2                      Employed full-time                Thailand
#
#           Student                                            EdLevel  \
# ...

# %%
df.sort_values(by=['Hobbyist'], ascending=[False]).head(4)
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 0               1  I am a student who is learning to code      Yes
# 23114       23243          I am a developer by profession      Yes
# 5755         5780          I am a developer by profession      Yes
# 5753         5778  I am a student who is learning to code      Yes
#
#                    OpenSourcer  \
# 0                        Never
# 23114                    Never
# 5755   Less than once per year
# 5753                     Never
#
#                                               OpenSource  \
# 0      The quality of OSS and closed source software ...
# 23114  The quality of OSS and closed source software ...
# 5755   The quality of OSS and closed source software ...
# 5753   The quality of OSS and closed source software ...
#
#                                    Employment                      Country  \
# 0      Not employed, and not looking for work               United Kingdom
# ...

# %%
df.sort_index().head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.sort_values(by='Country', inplace=True)

# %%
df['Country'].head(15)
# Out:
# 32971    Afghanistan
# 62124    Afghanistan
# 46807    Afghanistan
# 85827    Afghanistan
# 10697    Afghanistan
# 80423    Afghanistan
# 73920    Afghanistan
# 28470    Afghanistan
# 44123    Afghanistan
# 88340    Afghanistan
# 58082    Afghanistan
# 28877    Afghanistan
# 6391     Afghanistan
# 62723    Afghanistan
# 45562    Afghanistan
# Name: Country, dtype: object

# %%
df.nlargest(10, 'Respondent').head()
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 88330       88883                     I am a developer by profession      Yes
# 88329       88882                     I am a developer by profession      Yes
# 88328       88881                     I am a developer by profession      Yes
# 88327       88880  I am not primarily a developer, but I write co...      Yes
# 88326       88879                     I am a developer by profession      Yes
#
#                       OpenSourcer  \
# 88330  Once a month or more often
# 88329                       Never
# 88328  Once a month or more often
# 88327                       Never
# 88326                       Never
#
#                                               OpenSource          Employment  \
# 88330  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 88329  OSS is, on average, of LOWER quality than prop...  Employed full-time
# ...
