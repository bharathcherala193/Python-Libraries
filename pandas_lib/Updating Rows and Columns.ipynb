# %% [markdown]
# ## Updating,modifyRows and Columns

# %%
import pandas as pd

# %%
df=pd.read_csv('data.csv')

# %%
df.head(2)
# Out:
#    Respondent                              MainBranch Hobbyist  \
# 0           1  I am a student who is learning to code      Yes
# 1           2  I am a student who is learning to code       No
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
#
#   UndergradMajor  ...                            WelcomeChange  \
# ...

# %% [markdown]
#  ## rename

# %%
df.rename(columns={'Hobbyist': 'Hobby'}, inplace=True)

# %%
df.head(1)
# Out:
#    Respondent                              MainBranch Hobby OpenSourcer  \
# 0           1  I am a student who is learning to code   Yes       Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
#
#                                Employment         Country Student  \
# 0  Not employed, and not looking for work  United Kingdom      No
#
#                      EdLevel UndergradMajor  ...  \
# 0  Primary/elementary school            NaN  ...
#
#                              WelcomeChange  \
# 0  Just as welcome now as I felt last year
#
#                                         SONewContent   Age Gender Trans  \
# 0  Tech articles written by other developers;Indu...  14.0    Man    No
#
#                  Sexuality Ethnicity Dependents           SurveyLength  \
# 0  Straight / Heterosexual       NaN         No  Appropriate in length
#
#                    SurveyEase
# 0  Neither easy nor difficult
#
# ...

# %% [markdown]
# ## Map
# What is we want to change the responses a true boolean value (True or False)

# %%
df['Hobby'].map({'Yes': True, 'No': False})
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 88878     True
# 88879    False
# 88880    False
# 88881    False
# 88882     True
# Name: Hobby, Length: 88883, dtype: bool

# %%
# Change all columns to uppercase using a list comprehension:


df.columns = [x.upper() for x in df.columns]

# %%
df.head(1)
# Out:
#    RESPONDENT                              MAINBRANCH HOBBY OPENSOURCER  \
# 0           1  I am a student who is learning to code   Yes       Never
#
#                                           OPENSOURCE  \
# 0  The quality of OSS and closed source software ...
#
#                                EMPLOYMENT         COUNTRY STUDENT  \
# 0  Not employed, and not looking for work  United Kingdom      No
#
#                      EDLEVEL UNDERGRADMAJOR  ...  \
# 0  Primary/elementary school            NaN  ...
#
#                              WELCOMECHANGE  \
# 0  Just as welcome now as I felt last year
#
#                                         SONEWCONTENT   AGE GENDER TRANS  \
# 0  Tech articles written by other developers;Indu...  14.0    Man    No
#
#                  SEXUALITY ETHNICITY DEPENDENTS           SURVEYLENGTH  \
# 0  Straight / Heterosexual       NaN         No  Appropriate in length
#
#                    SURVEYEASE
# 0  Neither easy nor difficult
#
# ...

# %%
df.columns = [x.lower() for x in df.columns]

# %%
df.head(1)
# Out:
#    respondent                              mainbranch hobby opensourcer  \
# 0           1  I am a student who is learning to code   Yes       Never
#
#                                           opensource  \
# 0  The quality of OSS and closed source software ...
#
#                                employment         country student  \
# 0  Not employed, and not looking for work  United Kingdom      No
#
#                      edlevel undergradmajor  ...  \
# 0  Primary/elementary school            NaN  ...
#
#                              welcomechange  \
# 0  Just as welcome now as I felt last year
#
#                                         sonewcontent   age gender trans  \
# 0  Tech articles written by other developers;Indu...  14.0    Man    No
#
#                  sexuality ethnicity dependents           surveylength  \
# 0  Straight / Heterosexual       NaN         No  Appropriate in length
#
#                    surveyease
# 0  Neither easy nor difficult
#
# ...

# %%
df.loc[0,'opensource'] = ['John']

# %%
df.head(1)
# Out:
#    respondent                              mainbranch hobby opensourcer  \
# 0           1  I am a student who is learning to code   Yes       Never
#
#   opensource                              employment         country student  \
# 0     [John]  Not employed, and not looking for work  United Kingdom      No
#
#                      edlevel undergradmajor  ...  \
# 0  Primary/elementary school            NaN  ...
#
#                              welcomechange  \
# 0  Just as welcome now as I felt last year
#
#                                         sonewcontent   age gender trans  \
# 0  Tech articles written by other developers;Indu...  14.0    Man    No
#
#                  sexuality ethnicity dependents           surveylength  \
# 0  Straight / Heterosexual       NaN         No  Appropriate in length
#
#                    surveyease
# 0  Neither easy nor difficult
#
# [1 rows x 85 columns]

# %%
df['opensourcer'].str.lower()
# Out:
# 0                                                    never
# 1                                  less than once per year
# 2                                                    never
# 3                                                    never
# 4                               once a month or more often
#                                ...
# 88878    less than once a month but more than once per ...
# 88879                                                never
# 88880                                                never
# 88881                                                never
# 88882                              less than once per year
# Name: opensourcer, Length: 88883, dtype: object

# %%
df['hobby'].apply(len)
# Out:
# 0        3
# 1        2
# 2        3
# 3        2
# 4        3
#         ..
# 88878    3
# 88879    2
# 88880    2
# 88881    2
# 88882    3
# Name: hobby, Length: 88883, dtype: int64
