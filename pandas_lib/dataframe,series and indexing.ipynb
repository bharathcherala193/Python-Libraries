# %% [markdown]
# ## PANDAS
#
#   Pandas is a Python library used for:
#
#     -Data manipulation
#     -Data cleaning
#     -Data analysis
#     -Working with tabular data (rows & columns)
#     -Preparing data for ML

# %% [markdown]
#    # DataFrame and Series
#
#    -- Series is One-dimensional,abeled array,Holds any data type
#
#    --DataFrame is Two-dimensional,Collection of Series,Tabular data

# %%
import pandas as pd

# %%
people = {
    "first": ["Eren", "Iron", "Rob"],
    "last": ["yeager", "Man", "Roe"],
    "email": ["erenyeager@gmail.com", "ironman@email.com", "robroe@email.com"]
}

# %%
people["email"]
# Out:
# ['erenyeager@gmail.com', 'ironman@email.com', 'robroe@email.com']

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#   first    last                 email
# 0  Eren  yeager  erenyeager@gmail.com
# 1  Iron     Man     ironman@email.com
# 2   Rob     Roe      robroe@email.com

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['email']
# Out:
# 0    erenyeager@gmail.com
# 1       ironman@email.com
# 2        robroe@email.com
# Name: email, dtype: object

# %%
df[['last', 'email']]
# Out:
#      last                 email
# 0  yeager  erenyeager@gmail.com
# 1     Man     ironman@email.com
# 2     Roe      robroe@email.com

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df.iloc[0]
# Out:
# first                    Eren
# last                   yeager
# email    erenyeager@gmail.com
# Name: 0, dtype: object

# %%
df.loc[[0, 1]]
# Out:
#   first    last                 email
# 0  Eren  yeager  erenyeager@gmail.com
# 1  Iron     Man     ironman@email.com

# %%
df=pd.read_csv('data.csv')

# %% [markdown]
# Basic characteristics of dataframe

# %%
df.shape
# Out:
# (88883, 85)

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df['Hobbyist'].value_counts()
# Out:
# Hobbyist
# Yes    71257
# No     17626
# Name: count, dtype: int64

# %%
df.loc[[0, 1, 2], 'Hobbyist']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# Name: Hobbyist, dtype: object

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.loc[0, 'Hobbyist']
# Out:
# 'Yes'

# %%
df.loc[0:2, 'Hobbyist']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# Name: Hobbyist, dtype: object

# %%
df.loc[1:4,'MainBranch':'Student']
# Out:
#                                           MainBranch Hobbyist  \
# 1             I am a student who is learning to code       No
# 2  I am not primarily a developer, but I write co...      Yes
# 3                     I am a developer by profession       No
# 4                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
#                            Employment                 Country         Student
# 1  Not employed, but looking for work  Bosnia and Herzegovina  Yes, full-time
# ...

# %% [markdown]
# ## Indexes: How to Set, Reset and Use Indexes

# %%
df.index
# Out:
# RangeIndex(start=0, stop=88883, step=1)

# %%
df.sort_index()
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.sort_index(inplace=False)
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.loc[1]
# Out:
# Respondent                                                      2
# MainBranch                 I am a student who is learning to code
# Hobbyist                                                       No
# OpenSourcer                               Less than once per year
# OpenSource      The quality of OSS and closed source software ...
#                                       ...
# Sexuality                                 Straight / Heterosexual
# Ethnicity                                                     NaN
# Dependents                                                     No
# SurveyLength                                Appropriate in length
# SurveyEase                             Neither easy nor difficult
# Name: 1, Length: 85, dtype: object

# %%
df.loc[2,'OpenSourcer']
# Out:
# 'Never'
